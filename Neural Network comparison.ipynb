# %%
import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import random
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, KFold, cross_val_score
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from xgboost import XGBRegressor, XGBClassifier
from tqdm.auto import tqdm
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Load dataset
from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/My Drive/6004/project 2/code'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Settings

# %%
class icuDataset(Dataset):
  def __init__(self, x, y):
    super(icuDataset, self).__init__()
    # store the raw tensors
    self._x = x
    self._y = y

  def __len__(self):
    # size of Dataset
    return self._x.shape[0]

  def __getitem__(self, idx):
    if torch.is_tensor(idx):
      idx = idx.tolist()

    x = self._x[idx, :]
    y = self._y[idx]
    return x, y

# %%
def save_checkpoints(encoder, decoder, opt, checkpoint_path):
    save_dict = {}
    save_dict.update({'encoder': encoder.state_dict()})
    save_dict.update({'decoder': decoder.state_dict()})
    save_dict.update({'opt': opt.state_dict()})
    torch.save(save_dict, checkpoint_path)

def load_checkpoints(encoder, decoder, opt, checkpoint_path):
    ckpt = torch.load(checkpoint_path)
    encoder.load_state_dict(ckpt['encoder'])
    decoder.load_state_dict(ckpt['decoder'])
    opt.load_state_dict(ckpt['opt'])

# %%
# parameters

# datasets after preprocessing
file_path = '/content/drive/My Drive/6004/project2/code/clean_regress_id.csv'
data_2 = pd.read_csv(file_path)

# pre-defined global parameters
seed = 123
device = "cuda" if torch.cuda.is_available() else "cpu"

log_dir = 'models/'
if not os.path.exists(log_dir):
    os.makedirs(log_dir)

# set seeds
np.random.seed(seed)
random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

# %% [markdown]
# ## ICU duration (continuous) without death/discharge classification

# %%
y0 = torch.tensor(data_2['los_icu'], dtype = torch.float32)
X0 = torch.tensor(data_2.iloc[:, 2:].values, dtype = torch.float32)
# Verify the shapes
print("Shapes of X0 and y0:", X0.shape, y0.shape)
# Out:
# Shapes of X0 and y0: torch.Size([19199, 66]) torch.Size([19199])

# %%
X0_train, X0_test, y0_train, y0_test = train_test_split(X0, y0, test_size = 0.2, random_state = seed)

train_data_0 = icuDataset(X0_train, y0_train)
test_data_0 = icuDataset(X0_test, y0_test)

train_loader_0 = DataLoader(train_data_0, batch_size = 128, shuffle = True)
test_loader_0 = DataLoader(test_data_0, batch_size = 128, shuffle = False)

# %% [markdown]
# ### Neural network (FC)

# %%
class BaseRegressor(nn.Module):
    def __init__(self):
        super(BaseRegressor, self).__init__()
        self.fc_b1 = nn.Linear(66, 32)
        self.fc_b2 = nn.Linear(32, 1)

    def forward(self, x):
        x = F.relu(self.fc_b1(x))
        x = F.relu(self.fc_b2(x))
        return x

# %%
br = BaseRegressor().to(device)

# loss function
loss_func = torch.nn.MSELoss()

# optimizer
opt = optim.SGD(list(br.parameters()), lr = 0.0001, momentum = 0.9, weight_decay = 5e-4)

# %%
num_epochs = 200  # Set the number of epochs to 200
br_train_loss = []  # Initialize a list to store loss for each epoch

for epoch in range(1, num_epochs + 1):
    br.train()  # Set the model to training mode
    loss_list = []  # List to store losses for each batch in the current epoch

    for x, y in tqdm(train_loader_0, desc=f"Training Epoch #{epoch}"):
        x, y = x.to(device), y.to(device)  # Ensure data is on the correct device

        opt.zero_grad()  # Zero the gradients to prevent accumulation
        pred = br(x)  # Forward pass: compute predictions
        loss = loss_func(pred.squeeze(), y)  # Calculate loss; ensure dimensions match

        loss.backward()  # Backpropagate the errors
        opt.step()  # Update model parameters

        loss_list.append(loss.item())  # Append the loss for this batch to the list

    # Compute the average loss for this epoch
    epoch_loss = sum(loss_list) / len(loss_list)
    br_train_loss.append(epoch_loss)  # Append average loss to the training loss list

    # Print the average loss for the epoch
    print(f"Epoch {epoch}: Avg Loss = {epoch_loss:.4f}")
# Out:
# Training Epoch #1:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 1: Avg Loss = 16.6478
# Training Epoch #2:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 2: Avg Loss = 8.8631
# Training Epoch #3:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 3: Avg Loss = 7.9892
# Training Epoch #4:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 4: Avg Loss = 7.8767
# Training Epoch #5:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 5: Avg Loss = 7.8150
# Training Epoch #6:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 6: Avg Loss = 7.7742
# Training Epoch #7:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 7: Avg Loss = 7.7421
# Training Epoch #8:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 8: Avg Loss = 7.7159
# Training Epoch #9:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 9: Avg Loss = 7.6956
# Training Epoch #10:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 10: Avg Loss = 7.6774
# Training Epoch #11:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 11: Avg Loss = 7.6624
# Training Epoch #12:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 12: Avg Loss = 7.6479
# Training Epoch #13:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 13: Avg Loss = 7.6351
# Training Epoch #14:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 14: Avg Loss = 7.6241
# Training Epoch #15:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 15: Avg Loss = 7.6136
# Training Epoch #16:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 16: Avg Loss = 7.6041
# Training Epoch #17:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 17: Avg Loss = 7.5947
# Training Epoch #18:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 18: Avg Loss = 7.5865
# Training Epoch #19:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 19: Avg Loss = 7.5787
# Training Epoch #20:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 20: Avg Loss = 7.5723
# Training Epoch #21:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 21: Avg Loss = 7.5654
# Training Epoch #22:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 22: Avg Loss = 7.5576
# Training Epoch #23:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 23: Avg Loss = 7.5525
# Training Epoch #24:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 24: Avg Loss = 7.5461
# Training Epoch #25:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 25: Avg Loss = 7.5411
# Training Epoch #26:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 26: Avg Loss = 7.5362
# Training Epoch #27:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 27: Avg Loss = 7.5306
# Training Epoch #28:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 28: Avg Loss = 7.5258
# Training Epoch #29:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 29: Avg Loss = 7.5211
# Training Epoch #30:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 30: Avg Loss = 7.5169
# Training Epoch #31:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 31: Avg Loss = 7.5133
# Training Epoch #32:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 32: Avg Loss = 7.5079
# Training Epoch #33:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 33: Avg Loss = 7.5047
# Training Epoch #34:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 34: Avg Loss = 7.5006
# Training Epoch #35:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 35: Avg Loss = 7.4973
# Training Epoch #36:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 36: Avg Loss = 7.4950
# Training Epoch #37:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 37: Avg Loss = 7.4903
# Training Epoch #38:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 38: Avg Loss = 7.4871
# Training Epoch #39:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 39: Avg Loss = 7.4840
# Training Epoch #40:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 40: Avg Loss = 7.4809
# Training Epoch #41:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 41: Avg Loss = 7.4777
# Training Epoch #42:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 42: Avg Loss = 7.4747
# Training Epoch #43:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 43: Avg Loss = 7.4715
# Training Epoch #44:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 44: Avg Loss = 7.4687
# Training Epoch #45:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 45: Avg Loss = 7.4663
# Training Epoch #46:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 46: Avg Loss = 7.4623
# Training Epoch #47:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 47: Avg Loss = 7.4594
# Training Epoch #48:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 48: Avg Loss = 7.4575
# Training Epoch #49:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 49: Avg Loss = 7.4545
# Training Epoch #50:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 50: Avg Loss = 7.4532
# Training Epoch #51:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 51: Avg Loss = 7.4498
# Training Epoch #52:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 52: Avg Loss = 7.4476
# Training Epoch #53:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 53: Avg Loss = 7.4446
# Training Epoch #54:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 54: Avg Loss = 7.4419
# Training Epoch #55:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 55: Avg Loss = 7.4394
# Training Epoch #56:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 56: Avg Loss = 7.4355
# Training Epoch #57:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 57: Avg Loss = 7.4359
# Training Epoch #58:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 58: Avg Loss = 7.4328
# Training Epoch #59:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 59: Avg Loss = 7.4300
# Training Epoch #60:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 60: Avg Loss = 7.4278
# Training Epoch #61:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 61: Avg Loss = 7.4243
# Training Epoch #62:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 62: Avg Loss = 7.4227
# Training Epoch #63:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 63: Avg Loss = 7.4194
# Training Epoch #64:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 64: Avg Loss = 7.4165
# Training Epoch #65:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 65: Avg Loss = 7.4142
# Training Epoch #66:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 66: Avg Loss = 7.4118
# Training Epoch #67:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 67: Avg Loss = 7.4101
# Training Epoch #68:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 68: Avg Loss = 7.4070
# Training Epoch #69:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 69: Avg Loss = 7.4038
# Training Epoch #70:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 70: Avg Loss = 7.4008
# Training Epoch #71:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 71: Avg Loss = 7.3997
# Training Epoch #72:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 72: Avg Loss = 7.3949
# Training Epoch #73:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 73: Avg Loss = 7.3923
# Training Epoch #74:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 74: Avg Loss = 7.3922
# Training Epoch #75:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 75: Avg Loss = 7.3885
# Training Epoch #76:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 76: Avg Loss = 7.3863
# Training Epoch #77:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 77: Avg Loss = 7.3845
# Training Epoch #78:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 78: Avg Loss = 7.3808
# Training Epoch #79:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 79: Avg Loss = 7.3779
# Training Epoch #80:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 80: Avg Loss = 7.3754
# Training Epoch #81:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 81: Avg Loss = 7.3731
# Training Epoch #82:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 82: Avg Loss = 7.3689
# Training Epoch #83:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 83: Avg Loss = 7.3654
# Training Epoch #84:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 84: Avg Loss = 7.3642
# Training Epoch #85:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 85: Avg Loss = 7.3605
# Training Epoch #86:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 86: Avg Loss = 7.3590
# Training Epoch #87:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 87: Avg Loss = 7.3556
# Training Epoch #88:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 88: Avg Loss = 7.3532
# Training Epoch #89:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 89: Avg Loss = 7.3487
# Training Epoch #90:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 90: Avg Loss = 7.3457
# Training Epoch #91:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 91: Avg Loss = 7.3436
# Training Epoch #92:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 92: Avg Loss = 7.3402
# Training Epoch #93:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 93: Avg Loss = 7.3385
# Training Epoch #94:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 94: Avg Loss = 7.3345
# Training Epoch #95:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 95: Avg Loss = 7.3332
# Training Epoch #96:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 96: Avg Loss = 7.3289
# Training Epoch #97:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 97: Avg Loss = 7.3261
# Training Epoch #98:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 98: Avg Loss = 7.3225
# Training Epoch #99:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 99: Avg Loss = 7.3200
# Training Epoch #100:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 100: Avg Loss = 7.3175
# Training Epoch #101:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 101: Avg Loss = 7.3135
# Training Epoch #102:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 102: Avg Loss = 7.3097
# Training Epoch #103:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 103: Avg Loss = 7.3077
# Training Epoch #104:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 104: Avg Loss = 7.3054
# Training Epoch #105:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 105: Avg Loss = 7.3007
# Training Epoch #106:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 106: Avg Loss = 7.2981
# Training Epoch #107:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 107: Avg Loss = 7.2944
# Training Epoch #108:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 108: Avg Loss = 7.2935
# Training Epoch #109:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 109: Avg Loss = 7.2908
# Training Epoch #110:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 110: Avg Loss = 7.2860
# Training Epoch #111:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 111: Avg Loss = 7.2818
# Training Epoch #112:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 112: Avg Loss = 7.2786
# Training Epoch #113:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 113: Avg Loss = 7.2757
# Training Epoch #114:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 114: Avg Loss = 7.2721
# Training Epoch #115:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 115: Avg Loss = 7.2684
# Training Epoch #116:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 116: Avg Loss = 7.2652
# Training Epoch #117:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 117: Avg Loss = 7.2626
# Training Epoch #118:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 118: Avg Loss = 7.2590
# Training Epoch #119:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 119: Avg Loss = 7.2549
# Training Epoch #120:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 120: Avg Loss = 7.2520
# Training Epoch #121:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 121: Avg Loss = 7.2489
# Training Epoch #122:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 122: Avg Loss = 7.2437
# Training Epoch #123:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 123: Avg Loss = 7.2410
# Training Epoch #124:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 124: Avg Loss = 7.2367
# Training Epoch #125:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 125: Avg Loss = 7.2351
# Training Epoch #126:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 126: Avg Loss = 7.2303
# Training Epoch #127:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 127: Avg Loss = 7.2266
# Training Epoch #128:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 128: Avg Loss = 7.2238
# Training Epoch #129:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 129: Avg Loss = 7.2209
# Training Epoch #130:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 130: Avg Loss = 7.2172
# Training Epoch #131:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 131: Avg Loss = 7.2127
# Training Epoch #132:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 132: Avg Loss = 7.2097
# Training Epoch #133:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 133: Avg Loss = 7.2049
# Training Epoch #134:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 134: Avg Loss = 7.2033
# Training Epoch #135:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 135: Avg Loss = 7.1988
# Training Epoch #136:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 136: Avg Loss = 7.1953
# Training Epoch #137:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 137: Avg Loss = 7.1927
# Training Epoch #138:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 138: Avg Loss = 7.1874
# Training Epoch #139:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 139: Avg Loss = 7.1847
# Training Epoch #140:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 140: Avg Loss = 7.1814
# Training Epoch #141:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 141: Avg Loss = 7.1784
# Training Epoch #142:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 142: Avg Loss = 7.1771
# Training Epoch #143:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 143: Avg Loss = 7.1718
# Training Epoch #144:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 144: Avg Loss = 7.1684
# Training Epoch #145:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 145: Avg Loss = 7.1646
# Training Epoch #146:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 146: Avg Loss = 7.1611
# Training Epoch #147:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 147: Avg Loss = 7.1579
# Training Epoch #148:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 148: Avg Loss = 7.1530
# Training Epoch #149:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 149: Avg Loss = 7.1503
# Training Epoch #150:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 150: Avg Loss = 7.1457
# Training Epoch #151:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 151: Avg Loss = 7.1420
# Training Epoch #152:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 152: Avg Loss = 7.1390
# Training Epoch #153:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 153: Avg Loss = 7.1362
# Training Epoch #154:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 154: Avg Loss = 7.1319
# Training Epoch #155:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 155: Avg Loss = 7.1277
# Training Epoch #156:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 156: Avg Loss = 7.1253
# Training Epoch #157:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 157: Avg Loss = 7.1221
# Training Epoch #158:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 158: Avg Loss = 7.1179
# Training Epoch #159:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 159: Avg Loss = 7.1143
# Training Epoch #160:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 160: Avg Loss = 7.1111
# Training Epoch #161:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 161: Avg Loss = 7.1082
# Training Epoch #162:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 162: Avg Loss = 7.1044
# Training Epoch #163:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 163: Avg Loss = 7.1030
# Training Epoch #164:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 164: Avg Loss = 7.0996
# Training Epoch #165:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 165: Avg Loss = 7.0945
# Training Epoch #166:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 166: Avg Loss = 7.0904
# Training Epoch #167:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 167: Avg Loss = 7.0878
# Training Epoch #168:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 168: Avg Loss = 7.0835
# Training Epoch #169:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 169: Avg Loss = 7.0804
# Training Epoch #170:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 170: Avg Loss = 7.0765
# Training Epoch #171:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 171: Avg Loss = 7.0751
# Training Epoch #172:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 172: Avg Loss = 7.0689
# Training Epoch #173:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 173: Avg Loss = 7.0679
# Training Epoch #174:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 174: Avg Loss = 7.0637
# Training Epoch #175:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 175: Avg Loss = 7.0599
# Training Epoch #176:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 176: Avg Loss = 7.0584
# Training Epoch #177:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 177: Avg Loss = 7.0543
# Training Epoch #178:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 178: Avg Loss = 7.0504
# Training Epoch #179:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 179: Avg Loss = 7.0476
# Training Epoch #180:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 180: Avg Loss = 7.0458
# Training Epoch #181:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 181: Avg Loss = 7.0419
# Training Epoch #182:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 182: Avg Loss = 7.0384
# Training Epoch #183:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 183: Avg Loss = 7.0367
# Training Epoch #184:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 184: Avg Loss = 7.0323
# Training Epoch #185:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 185: Avg Loss = 7.0294
# Training Epoch #186:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 186: Avg Loss = 7.0273
# Training Epoch #187:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 187: Avg Loss = 7.0230
# Training Epoch #188:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 188: Avg Loss = 7.0192
# Training Epoch #189:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 189: Avg Loss = 7.0166
# Training Epoch #190:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 190: Avg Loss = 7.0128
# Training Epoch #191:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 191: Avg Loss = 7.0109
# Training Epoch #192:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 192: Avg Loss = 7.0053
# Training Epoch #193:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 193: Avg Loss = 7.0029
# Training Epoch #194:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 194: Avg Loss = 7.0008
# Training Epoch #195:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 195: Avg Loss = 6.9966
# Training Epoch #196:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 196: Avg Loss = 6.9936
# Training Epoch #197:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 197: Avg Loss = 6.9901
# Training Epoch #198:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 198: Avg Loss = 6.9875
# Training Epoch #199:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 199: Avg Loss = 6.9844
# Training Epoch #200:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 200: Avg Loss = 6.9804

# %%
epochs = range(1, len(br_train_loss) + 1)  # Adjust epochs to match the length of train_loss

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, br_train_loss, label='Training Loss', marker='o', color='blue')
plt.title('Training Loss Per Epoch')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Set the model to evaluation mode
br.eval()

# Initialize variables to store the cumulative loss and count of samples processed
total_loss = 0.0
count = 0

# No gradient computations needed during testing
with torch.no_grad():
    for x, y in tqdm(test_loader_0, desc="Testing"):
        x, y = x.to(device), y.to(device)  # Ensure data is on the correct device

        # Forward pass: compute predictions
        pred = br(x)
        loss = loss_func(pred.squeeze(), y)  # Calculate loss, ensure dimensions match

        # Accumulate the total loss and the number of samples
        total_loss += loss.item() * x.size(0)
        count += x.size(0)

# Compute the average loss across all test data
average_loss = total_loss / count if count != 0 else 0

# Print the average loss for the testing phase
print(f"Average Test Loss: {average_loss:.4f}")
# Out:
# Testing:   0%|          | 0/30 [00:00<?, ?it/s]
# Average Test Loss: 7.1948

# %% [markdown]
# ### Neural Network (LSTM encoder)

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers=1, bidirectional=False):
        super(Encoder, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers=num_layers, batch_first=True, bidirectional=bidirectional)
        self.feature_dim = hidden_dim * 2 if bidirectional else hidden_dim

    def forward(self, x):
        _, (hidden, _) = self.lstm(x)
        # Ensure consistent dimensionality regardless of the batch size
        if hidden.dim() == 2:
            hidden = hidden.unsqueeze(0)  # Add a batch dimension if it's missing

        if self.lstm.bidirectional:
            # Concatenate the hidden states from both directions
            hidden = torch.cat((hidden[-2], hidden[-1]), dim=1)
        else:
            # Get the last layer's last direction output
            hidden = hidden[-1]

        return hidden

# %%
class Regressor(nn.Module):
    def __init__(self, input_dim):
        super(Regressor, self).__init__()
        self.fc_b1 = nn.Linear(input_dim, 32)
        self.fc_b2 = nn.Linear(32, 1)

    def forward(self, x):
        x = F.relu(self.fc_b1(x))
        x = self.fc_b2(x)
        return x

# %%
input_dim = 66  # Input dimensionality
hidden_dim = 64  # Hidden state dimensionality

# Initialize Encoder
encoder = Encoder(input_dim, hidden_dim).to(device)
# Initialize Regressor with encoder's feature_dim
regressor = Regressor(input_dim=encoder.feature_dim).to(device)

# %%
# Loss function
loss_func = nn.MSELoss()

# Optimizer
optimizer = optim.SGD(list(encoder.parameters()) + list(regressor.parameters()), lr=0.0001, momentum=0.9, weight_decay=5e-4)

num_epochs = 200

# %%
#training loop
train_loss = []
for epoch in range(1, num_epochs + 1):
    encoder.train()
    regressor.train()
    epoch_loss_list = []

    for x, y in train_loader_0:
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        embedding = encoder(x)
        pred = regressor(embedding)

        loss = loss_func(pred, y)
        loss.backward()
        optimizer.step()

        epoch_loss_list.append(loss.item())



    if len(epoch_loss_list) == 0:
        print("Warning: No data processed this epoch")
        average_loss = 0

    else:
        average_loss = sum(epoch_loss_list) / len(epoch_loss_list)


    train_loss.append(average_loss)


    print(f'Epoch {epoch}: Avg Loss = {average_loss:.4f}')
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([128])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([127])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 1: Avg Loss = 17.3618
# Epoch 2: Avg Loss = 11.4263
# Epoch 3: Avg Loss = 8.3001
# Epoch 4: Avg Loss = 7.8960
# Epoch 5: Avg Loss = 7.8913
# Epoch 6: Avg Loss = 7.8925
# Epoch 7: Avg Loss = 7.8851
# Epoch 8: Avg Loss = 7.8866
# Epoch 9: Avg Loss = 7.8919
# Epoch 10: Avg Loss = 7.8921
# Epoch 11: Avg Loss = 7.8977
# Epoch 12: Avg Loss = 7.8827
# Epoch 13: Avg Loss = 7.8885
# Epoch 14: Avg Loss = 7.8843
# Epoch 15: Avg Loss = 7.8873
# Epoch 16: Avg Loss = 7.8867
# Epoch 17: Avg Loss = 7.8767
# Epoch 18: Avg Loss = 7.8829
# Epoch 19: Avg Loss = 7.9101
# Epoch 20: Avg Loss = 7.8763
# Epoch 21: Avg Loss = 7.8817
# Epoch 22: Avg Loss = 7.8893
# Epoch 23: Avg Loss = 7.8861
# Epoch 24: Avg Loss = 7.8827
# Epoch 25: Avg Loss = 7.8761
# Epoch 26: Avg Loss = 7.8838
# Epoch 27: Avg Loss = 7.8964
# Epoch 28: Avg Loss = 7.8754
# Epoch 29: Avg Loss = 7.8766
# Epoch 30: Avg Loss = 7.8738
# Epoch 31: Avg Loss = 7.8838
# Epoch 32: Avg Loss = 7.8768
# Epoch 33: Avg Loss = 7.8815
# Epoch 34: Avg Loss = 7.8720
# Epoch 35: Avg Loss = 7.8816
# Epoch 36: Avg Loss = 7.8754
# Epoch 37: Avg Loss = 7.8849
# Epoch 38: Avg Loss = 7.8811
# Epoch 39: Avg Loss = 7.8843
# Epoch 40: Avg Loss = 7.8752
# Epoch 41: Avg Loss = 7.8753
# Epoch 42: Avg Loss = 7.8818
# Epoch 43: Avg Loss = 7.8746
# Epoch 44: Avg Loss = 7.8756
# Epoch 45: Avg Loss = 7.8740
# Epoch 46: Avg Loss = 7.8722
# Epoch 47: Avg Loss = 7.8730
# Epoch 48: Avg Loss = 7.8767
# Epoch 49: Avg Loss = 7.8757
# Epoch 50: Avg Loss = 7.8881
# Epoch 51: Avg Loss = 7.8751
# Epoch 52: Avg Loss = 7.8736
# Epoch 53: Avg Loss = 7.8751
# Epoch 54: Avg Loss = 7.8821
# Epoch 55: Avg Loss = 7.8817
# Epoch 56: Avg Loss = 7.8713
# Epoch 57: Avg Loss = 7.8702
# Epoch 58: Avg Loss = 7.8775
# Epoch 59: Avg Loss = 7.8775
# Epoch 60: Avg Loss = 7.8753
# Epoch 61: Avg Loss = 7.8743
# Epoch 62: Avg Loss = 7.8790
# Epoch 63: Avg Loss = 7.8742
# Epoch 64: Avg Loss = 7.8753
# Epoch 65: Avg Loss = 7.8769
# Epoch 66: Avg Loss = 7.8783
# Epoch 67: Avg Loss = 7.8749
# Epoch 68: Avg Loss = 7.8716
# Epoch 69: Avg Loss = 7.8730
# Epoch 70: Avg Loss = 7.8731
# Epoch 71: Avg Loss = 7.8726
# Epoch 72: Avg Loss = 7.8744
# Epoch 73: Avg Loss = 7.8744
# Epoch 74: Avg Loss = 7.8754
# Epoch 75: Avg Loss = 7.8788
# Epoch 76: Avg Loss = 7.8752
# Epoch 77: Avg Loss = 7.8798
# Epoch 78: Avg Loss = 7.8751
# Epoch 79: Avg Loss = 7.8765
# Epoch 80: Avg Loss = 7.8676
# Epoch 81: Avg Loss = 7.8743
# Epoch 82: Avg Loss = 7.8683
# Epoch 83: Avg Loss = 7.8787
# Epoch 84: Avg Loss = 7.8792
# Epoch 85: Avg Loss = 7.8745
# Epoch 86: Avg Loss = 7.8654
# Epoch 87: Avg Loss = 7.8731
# Epoch 88: Avg Loss = 7.8765
# Epoch 89: Avg Loss = 7.8814
# Epoch 90: Avg Loss = 7.8724
# Epoch 91: Avg Loss = 7.8676
# Epoch 92: Avg Loss = 7.8746
# Epoch 93: Avg Loss = 7.8731
# Epoch 94: Avg Loss = 7.8778
# Epoch 95: Avg Loss = 7.8715
# Epoch 96: Avg Loss = 7.8723
# Epoch 97: Avg Loss = 7.8783
# Epoch 98: Avg Loss = 7.8758
# Epoch 99: Avg Loss = 7.8794
# Epoch 100: Avg Loss = 7.8742
# Epoch 101: Avg Loss = 7.8703
# Epoch 102: Avg Loss = 7.8706
# Epoch 103: Avg Loss = 7.8731
# Epoch 104: Avg Loss = 7.8728
# Epoch 105: Avg Loss = 7.8733
# Epoch 106: Avg Loss = 7.8687
# Epoch 107: Avg Loss = 7.8716
# Epoch 108: Avg Loss = 7.8675
# Epoch 109: Avg Loss = 7.8704
# Epoch 110: Avg Loss = 7.8746
# Epoch 111: Avg Loss = 7.8734
# Epoch 112: Avg Loss = 7.8711
# Epoch 113: Avg Loss = 7.8745
# Epoch 114: Avg Loss = 7.8717
# Epoch 115: Avg Loss = 7.8728
# Epoch 116: Avg Loss = 7.8756
# Epoch 117: Avg Loss = 7.8648
# Epoch 118: Avg Loss = 7.8706
# Epoch 119: Avg Loss = 7.8716
# Epoch 120: Avg Loss = 7.8704
# Epoch 121: Avg Loss = 7.8747
# Epoch 122: Avg Loss = 7.8681
# Epoch 123: Avg Loss = 7.8671
# Epoch 124: Avg Loss = 7.8712
# Epoch 125: Avg Loss = 7.8771
# Epoch 126: Avg Loss = 7.8703
# Epoch 127: Avg Loss = 7.8705
# Epoch 128: Avg Loss = 7.8692
# Epoch 129: Avg Loss = 7.8717
# Epoch 130: Avg Loss = 7.8702
# Epoch 131: Avg Loss = 7.8706
# Epoch 132: Avg Loss = 7.8746
# Epoch 133: Avg Loss = 7.8694
# Epoch 134: Avg Loss = 7.8681
# Epoch 135: Avg Loss = 7.8720
# Epoch 136: Avg Loss = 7.8733
# Epoch 137: Avg Loss = 7.8727
# Epoch 138: Avg Loss = 7.8753
# Epoch 139: Avg Loss = 7.8705
# Epoch 140: Avg Loss = 7.8760
# Epoch 141: Avg Loss = 7.8697
# Epoch 142: Avg Loss = 7.8680
# Epoch 143: Avg Loss = 7.8757
# Epoch 144: Avg Loss = 7.8717
# Epoch 145: Avg Loss = 7.8719
# Epoch 146: Avg Loss = 7.8753
# Epoch 147: Avg Loss = 7.8691
# Epoch 148: Avg Loss = 7.8680
# Epoch 149: Avg Loss = 7.8686
# Epoch 150: Avg Loss = 7.8702
# Epoch 151: Avg Loss = 7.8718
# Epoch 152: Avg Loss = 7.8723
# Epoch 153: Avg Loss = 7.8745
# Epoch 154: Avg Loss = 7.8692
# Epoch 155: Avg Loss = 7.8690
# Epoch 156: Avg Loss = 7.8723
# Epoch 157: Avg Loss = 7.8753
# Epoch 158: Avg Loss = 7.8718
# Epoch 159: Avg Loss = 7.8721
# Epoch 160: Avg Loss = 7.8699
# Epoch 161: Avg Loss = 7.8721
# Epoch 162: Avg Loss = 7.8698
# Epoch 163: Avg Loss = 7.8704
# Epoch 164: Avg Loss = 7.8740
# Epoch 165: Avg Loss = 7.8702
# Epoch 166: Avg Loss = 7.8682
# Epoch 167: Avg Loss = 7.8724
# Epoch 168: Avg Loss = 7.8737
# Epoch 169: Avg Loss = 7.8743
# Epoch 170: Avg Loss = 7.8712
# Epoch 171: Avg Loss = 7.8742
# Epoch 172: Avg Loss = 7.8734
# Epoch 173: Avg Loss = 7.8735
# Epoch 174: Avg Loss = 7.8756
# Epoch 175: Avg Loss = 7.8710
# Epoch 176: Avg Loss = 7.8689
# Epoch 177: Avg Loss = 7.8737
# Epoch 178: Avg Loss = 7.8693
# Epoch 179: Avg Loss = 7.8718
# Epoch 180: Avg Loss = 7.8698
# Epoch 181: Avg Loss = 7.8723
# Epoch 182: Avg Loss = 7.8716
# Epoch 183: Avg Loss = 7.8721
# Epoch 184: Avg Loss = 7.8729
# Epoch 185: Avg Loss = 7.8734
# Epoch 186: Avg Loss = 7.8704
# Epoch 187: Avg Loss = 7.8742
# Epoch 188: Avg Loss = 7.8718
# Epoch 189: Avg Loss = 7.8719
# Epoch 190: Avg Loss = 7.8739
# Epoch 191: Avg Loss = 7.8698
# Epoch 192: Avg Loss = 7.8680
# Epoch 193: Avg Loss = 7.8718
# Epoch 194: Avg Loss = 7.8745
# Epoch 195: Avg Loss = 7.8688
# Epoch 196: Avg Loss = 7.8734
# Epoch 197: Avg Loss = 7.8754
# Epoch 198: Avg Loss = 7.8739
# Epoch 199: Avg Loss = 7.8704
# Epoch 200: Avg Loss = 7.8730

# %%
batches_per_epoch = len(train_loader_0)
total_batches = num_epochs * batches_per_epoch
epochs = range(1, total_batches + 1)

# %%
epochs = range(1, len(train_loss) + 1)  # Adjust epochs to match the length of train_loss

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, label='Training Loss', marker='o', color='blue')
plt.title('Training Loss Per Epoch')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
test_loss = []


encoder.eval()
regressor.eval()

with torch.no_grad():
    for x, y in test_loader_0:
        x, y = x.to(device), y.to(device)

        embedding = encoder(x)
        pred = regressor(embedding)

        loss = loss_func(pred, y)
        test_loss.append(loss.item())

average_test_loss = sum(test_loss) / len(test_loss)


print(f'Test Results - Average Loss: {average_test_loss:.4f}')
# Out:
# Test Results - Average Loss: 7.7115

# %% [markdown]
# ###NN combinded (linear+LSTM encoder)

# %%
class CombinedEncoder(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers=1, bidirectional=False):
        super(CombinedEncoder, self).__init__()
        # Initialize BaseRegressor and Encoder
        self.base_regressor = BaseRegressor()
        self.encoder = Encoder(input_dim, hidden_dim, num_layers, bidirectional)
        self.final_regressor = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        output_base = self.base_regressor(x)
        output_encoder = self.encoder(x)
        summed_output = output_base + output_encoder
        final_output = self.final_regressor(summed_output)
        return final_output

# %%
class Regressor(nn.Module):
    def __init__(self, input_dim):
        super(Regressor, self).__init__()
        self.fc_b1 = nn.Linear(input_dim, 32)
        self.fc_b2 = nn.Linear(32, 1)

    def forward(self, x):
        x = F.relu(self.fc_b1(x))
        x = self.fc_b2(x) #no activation function here, allowing for unbounded output
        return x

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = CombinedEncoder(input_dim=66, hidden_dim=32, num_layers=1, bidirectional=False)
model.to(device)

# Loss function and optimizer
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.00001)

# %%
num_epochs = 200
epoch_losses = []
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0


    for inputs, labels in train_loader_0:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)  # Forward pass
        loss = criterion(outputs, labels)  # Calculate the loss

        loss.backward()  # Backward pass and optimize
        optimizer.step()

        # Statistics
        running_loss += loss.item() * inputs.size(0)


    epoch_loss = running_loss / len(train_loader_0.dataset)
    epoch_losses.append(epoch_loss)  # Append the epoch loss
    print(f'Epoch {epoch + 1}/{num_epochs}, Loss: {epoch_loss:.4f}')
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([128])) that is different to the input size (torch.Size([128, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([127])) that is different to the input size (torch.Size([127, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 1/200, Loss: 22.2180
# Epoch 2/200, Loss: 22.0217
# Epoch 3/200, Loss: 21.8113
# Epoch 4/200, Loss: 21.7588
# Epoch 5/200, Loss: 21.6077
# Epoch 6/200, Loss: 21.4029
# Epoch 7/200, Loss: 21.3195
# Epoch 8/200, Loss: 21.1057
# Epoch 9/200, Loss: 20.9305
# Epoch 10/200, Loss: 20.8540
# Epoch 11/200, Loss: 20.6927
# Epoch 12/200, Loss: 20.4371
# Epoch 13/200, Loss: 20.2774
# Epoch 14/200, Loss: 20.0177
# Epoch 15/200, Loss: 19.7801
# Epoch 16/200, Loss: 19.7320
# Epoch 17/200, Loss: 19.5041
# Epoch 18/200, Loss: 19.1691
# Epoch 19/200, Loss: 18.8415
# Epoch 20/200, Loss: 18.5452
# Epoch 21/200, Loss: 18.1627
# Epoch 22/200, Loss: 17.7704
# Epoch 23/200, Loss: 17.4429
# Epoch 24/200, Loss: 17.1083
# Epoch 25/200, Loss: 16.6756
# Epoch 26/200, Loss: 15.9059
# Epoch 27/200, Loss: 15.4326
# Epoch 28/200, Loss: 14.7630
# Epoch 29/200, Loss: 14.3429
# Epoch 30/200, Loss: 13.7579
# Epoch 31/200, Loss: 13.1066
# Epoch 32/200, Loss: 12.6150
# Epoch 33/200, Loss: 12.2287
# Epoch 34/200, Loss: 11.7876
# Epoch 35/200, Loss: 11.3655
# Epoch 36/200, Loss: 11.0408
# Epoch 37/200, Loss: 10.7397
# Epoch 38/200, Loss: 10.4628
# Epoch 39/200, Loss: 10.1501
# Epoch 40/200, Loss: 9.9832
# Epoch 41/200, Loss: 9.6763
# Epoch 42/200, Loss: 9.4937
# Epoch 43/200, Loss: 9.2811
# Epoch 44/200, Loss: 9.1623
# Epoch 45/200, Loss: 9.0183
# Epoch 46/200, Loss: 8.8389
# Epoch 47/200, Loss: 8.7328
# Epoch 48/200, Loss: 8.6464
# Epoch 49/200, Loss: 8.5070
# Epoch 50/200, Loss: 8.4527
# Epoch 51/200, Loss: 8.3456
# Epoch 52/200, Loss: 8.3415
# Epoch 53/200, Loss: 8.2954
# Epoch 54/200, Loss: 8.2186
# Epoch 55/200, Loss: 8.1109
# Epoch 56/200, Loss: 8.1190
# Epoch 57/200, Loss: 8.0664
# Epoch 58/200, Loss: 8.0312
# Epoch 59/200, Loss: 8.0045
# Epoch 60/200, Loss: 7.9974
# Epoch 61/200, Loss: 7.9815
# Epoch 62/200, Loss: 7.9909
# Epoch 63/200, Loss: 7.9450
# Epoch 64/200, Loss: 7.9229
# Epoch 65/200, Loss: 7.9126
# Epoch 66/200, Loss: 7.8987
# Epoch 67/200, Loss: 7.9107
# Epoch 68/200, Loss: 7.9035
# Epoch 69/200, Loss: 7.8988
# Epoch 70/200, Loss: 7.8925
# Epoch 71/200, Loss: 7.8822
# Epoch 72/200, Loss: 7.8891
# Epoch 73/200, Loss: 7.8854
# Epoch 74/200, Loss: 7.8919
# Epoch 75/200, Loss: 7.8948
# Epoch 76/200, Loss: 7.8800
# Epoch 77/200, Loss: 7.8779
# Epoch 78/200, Loss: 7.8755
# Epoch 79/200, Loss: 7.8770
# Epoch 80/200, Loss: 7.8890
# Epoch 81/200, Loss: 7.8737
# Epoch 82/200, Loss: 7.8771
# Epoch 83/200, Loss: 7.8752
# Epoch 84/200, Loss: 7.8787
# Epoch 85/200, Loss: 7.8838
# Epoch 86/200, Loss: 7.8855
# Epoch 87/200, Loss: 7.8825
# Epoch 88/200, Loss: 7.8812
# Epoch 89/200, Loss: 7.8786
# Epoch 90/200, Loss: 7.8734
# Epoch 91/200, Loss: 7.8843
# Epoch 92/200, Loss: 7.8740
# Epoch 93/200, Loss: 7.8798
# Epoch 94/200, Loss: 7.8693
# Epoch 95/200, Loss: 7.8752
# Epoch 96/200, Loss: 7.8749
# Epoch 97/200, Loss: 7.8760
# Epoch 98/200, Loss: 7.8746
# Epoch 99/200, Loss: 7.8744
# Epoch 100/200, Loss: 7.8831
# Epoch 101/200, Loss: 7.8796
# Epoch 102/200, Loss: 7.8779
# Epoch 103/200, Loss: 7.8743
# Epoch 104/200, Loss: 7.8897
# Epoch 105/200, Loss: 7.8757
# Epoch 106/200, Loss: 7.8795
# Epoch 107/200, Loss: 7.8872
# Epoch 108/200, Loss: 7.8806
# Epoch 109/200, Loss: 7.8928
# Epoch 110/200, Loss: 7.8860
# Epoch 111/200, Loss: 7.8865
# Epoch 112/200, Loss: 7.8740
# Epoch 113/200, Loss: 7.8830
# Epoch 114/200, Loss: 7.8833
# Epoch 115/200, Loss: 7.8817
# Epoch 116/200, Loss: 7.8764
# Epoch 117/200, Loss: 7.8817
# Epoch 118/200, Loss: 7.8750
# Epoch 119/200, Loss: 7.8783
# Epoch 120/200, Loss: 7.8730
# Epoch 121/200, Loss: 7.8777
# Epoch 122/200, Loss: 7.8807
# Epoch 123/200, Loss: 7.8732
# Epoch 124/200, Loss: 7.8846
# Epoch 125/200, Loss: 7.8846
# Epoch 126/200, Loss: 7.8720
# Epoch 127/200, Loss: 7.8694
# Epoch 128/200, Loss: 7.8770
# Epoch 129/200, Loss: 7.8672
# Epoch 130/200, Loss: 7.8862
# Epoch 131/200, Loss: 7.8858
# Epoch 132/200, Loss: 7.8757
# Epoch 133/200, Loss: 7.8722
# Epoch 134/200, Loss: 7.8707
# Epoch 135/200, Loss: 7.8750
# Epoch 136/200, Loss: 7.8891
# Epoch 137/200, Loss: 7.8769
# Epoch 138/200, Loss: 7.8744
# Epoch 139/200, Loss: 7.8710
# Epoch 140/200, Loss: 7.8825
# Epoch 141/200, Loss: 7.8774
# Epoch 142/200, Loss: 7.8703
# Epoch 143/200, Loss: 7.8921
# Epoch 144/200, Loss: 7.8744
# Epoch 145/200, Loss: 7.8807
# Epoch 146/200, Loss: 7.8724
# Epoch 147/200, Loss: 7.8749
# Epoch 148/200, Loss: 7.8732
# Epoch 149/200, Loss: 7.8752
# Epoch 150/200, Loss: 7.8703
# Epoch 151/200, Loss: 7.8713
# Epoch 152/200, Loss: 7.8767
# Epoch 153/200, Loss: 7.8703
# Epoch 154/200, Loss: 7.8678
# Epoch 155/200, Loss: 7.8710
# Epoch 156/200, Loss: 7.8759
# Epoch 157/200, Loss: 7.8875
# Epoch 158/200, Loss: 7.8788
# Epoch 159/200, Loss: 7.8756
# Epoch 160/200, Loss: 7.8722
# Epoch 161/200, Loss: 7.8775
# Epoch 162/200, Loss: 7.8704
# Epoch 163/200, Loss: 7.8785
# Epoch 164/200, Loss: 7.8755
# Epoch 165/200, Loss: 7.8733
# Epoch 166/200, Loss: 7.8741
# Epoch 167/200, Loss: 7.8726
# Epoch 168/200, Loss: 7.8785
# Epoch 169/200, Loss: 7.8723
# Epoch 170/200, Loss: 7.8685
# Epoch 171/200, Loss: 7.8784
# Epoch 172/200, Loss: 7.8724
# Epoch 173/200, Loss: 7.8717
# Epoch 174/200, Loss: 7.8714
# Epoch 175/200, Loss: 7.8786
# Epoch 176/200, Loss: 7.8745
# Epoch 177/200, Loss: 7.8675
# Epoch 178/200, Loss: 7.8722
# Epoch 179/200, Loss: 7.8766
# Epoch 180/200, Loss: 7.8776
# Epoch 181/200, Loss: 7.8701
# Epoch 182/200, Loss: 7.8772
# Epoch 183/200, Loss: 7.8698
# Epoch 184/200, Loss: 7.8853
# Epoch 185/200, Loss: 7.8778
# Epoch 186/200, Loss: 7.9021
# Epoch 187/200, Loss: 7.8761
# Epoch 188/200, Loss: 7.8763
# Epoch 189/200, Loss: 7.8708
# Epoch 190/200, Loss: 7.8703
# Epoch 191/200, Loss: 7.8663
# Epoch 192/200, Loss: 7.8737
# Epoch 193/200, Loss: 7.8684
# Epoch 194/200, Loss: 7.8711
# Epoch 195/200, Loss: 7.8765
# Epoch 196/200, Loss: 7.8777
# Epoch 197/200, Loss: 7.8717
# Epoch 198/200, Loss: 7.8766
# Epoch 199/200, Loss: 7.8762
# Epoch 200/200, Loss: 7.8754

# %%
model.eval()
test_loss = 0.0


with torch.no_grad():
    for inputs, labels in test_loader_0:
        inputs, labels = inputs.to(device), labels.to(device)

        outputs = model(inputs)  # Forward pass
        loss = criterion(outputs, labels)  # Calculate the loss


        test_loss += loss.item() * inputs.size(0)


# Calculate average loss over the testing dataset
test_loss /= len(test_loader_0.dataset)


print(f'Test Loss: {test_loss:.4f}')
# Out:
# Test Loss: 7.7076

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs + 1), epoch_losses, marker='o', linestyle='-', color='b', label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Over Epochs')
plt.legend()
plt.grid(True)
plt.show()
